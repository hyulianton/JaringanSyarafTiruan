# %% [markdown]
# <a href="https://colab.research.google.com/github/hyulianton/JaringanSyarafTiruan/blob/main/jst_Generasi_Teks_dengan_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Proyek: Generasi Teks Karakter-Level dengan LSTM
#
# Ini adalah implementasi dasar dari Recurrent Neural Network (RNN) dengan arsitektur Long Short-Term Memory (LSTM) untuk memprediksi karakter teks berikutnya. Tujuannya adalah melatih model agar dapat menghasilkan teks baru yang meniru gaya dan pola dari korpus teks pelatihan.
#
# ### Cell 1: Setup Lingkungan dan Import Library
#
# Sel ini melakukan impor semua library yang diperlukan, yaitu NumPy untuk operasi array, dan TensorFlow/Keras untuk membangun serta melatih model jaringan saraf. Pengecekan GPU juga disertakan untuk optimasi performa.

# %%
# Import library yang diperlukan
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
from tensorflow.keras.optimizers import RMSprop
import random
import sys
import time

# Pengecekan Versi dan Ketersediaan GPU
# Penggunaan GPU sangat disarankan untuk pelatihan model Neural Network
print(f"Versi TensorFlow: {tf.__version__}")
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f"GPU tersedia dan akan digunakan: {gpu_devices}")
else:
    print("GPU tidak tersedia. TensorFlow akan menggunakan CPU.")
# Out:
# Versi TensorFlow: 2.19.0
# GPU tersedia dan akan digunakan: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Cell 2: Persiapan Data Teks (Korpus)
#
# Korpus teks adalah data mentah yang akan dipelajari oleh model. Dalam sel ini, kita memuat teks, mengubahnya menjadi huruf kecil, dan membuat dua *mapping* penting: dari karakter ke integer (`char_to_int`) dan sebaliknya (`int_to_char`).
#
# **Konsep Kunci:** Pemetaan karakter ke integer diperlukan karena Neural Network hanya dapat memproses data numerik.

# %%
# --- 1. Persiapan Data (Load dan Preprocess) ---
print("--- Memuat dan Memproses Data ---")

# Korpus Teks Sederhana untuk demonstrasi.
# Untuk hasil yang lebih menarik, ganti teks ini dengan korpus yang lebih besar (misalnya novel).
text = """Hai teman-teman! Selamat datang di perkuliahan Jaringan Syaraf Tiruan.
Kali ini kita akan membahas Recurrent Neural Networks dan Long Short-Term Memory.
Semoga kalian semua enjoy dan memahami materi ini dengan baik.
Jangan sungkan bertanya jika ada yang kurang jelas, ya!
AI itu keren banget, bukan?"""

# Ubah teks menjadi huruf kecil semua
text = text.lower()
print(f'Panjang total korpus teks: {len(text)} karakter.')

# Temukan semua karakter unik yang ada di teks (vocabulary)
chars = sorted(list(set(text)))
print(f'Total karakter unik (vocabulary size): {len(chars)}')
# print(f'Karakter unik: {chars}') # Uncomment untuk melihat semua karakter unik

# Buat mapping dari karakter ke integer dan sebaliknya
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# --- Memuat dan Memproses Data ---
# Panjang total korpus teks: 299 karakter.
# Total karakter unik (vocabulary size): 29

# %% [markdown]
# ### Cell 3: Pembentukan Sekuens Input dan Vectorisasi
#
# Model LSTM dilatih menggunakan sekuens. Kita menggunakan teknik **Sliding Window** untuk membuat banyak pasangan input (urutan 40 karakter) dan target (karakter ke-41).
#
# **One-Hot Encoding** dilakukan untuk mengubah data sekuensial karakter menjadi format tensor biner yang dapat diterima oleh layer LSTM.

# %%
# --- 2. Menyiapkan Data Pelatihan (Sequences) ---
print("\n--- Menyiapkan Data Sekuensial untuk Pelatihan ---")

SEQUENCE_LENGTH = 40 # Panjang sekuens input (konteks)
step = 3             # Jarak pergeseran window

sentences = []   # Input (X): sekuens 40 karakter
next_chars = []  # Output (y): karakter berikutnya

# Lakukan sliding window
for i in range(0, len(text) - SEQUENCE_LENGTH, step):
    sentences.append(text[i: i + SEQUENCE_LENGTH])
    next_chars.append(text[i + SEQUENCE_LENGTH])

print(f'Jumlah sekuens pelatihan yang dibuat: {len(sentences)}')

# Vectorisasi data: Ubah karakter menjadi one-hot encoding
# X: (jumlah_sekuens, SEQUENCE_LENGTH, jumlah_karakter_unik)
# y: (jumlah_sekuens, jumlah_karakter_unik)
X = np.zeros((len(sentences), SEQUENCE_LENGTH, len(chars)), dtype=np.bool_)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool_)

# Isi array X dan y
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        # One-hot encoding untuk input X
        X[i, t, char_to_int[char]] = 1
    # One-hot encoding untuk target y
    y[i, char_to_int[next_chars[i]]] = 1

print(f'Bentuk data input (X): {X.shape}')
print(f'Bentuk data target (y): {y.shape}')
# Out:
# --- Menyiapkan Data Sekuensial untuk Pelatihan ---
# Jumlah sekuens pelatihan yang dibuat: 87
# Bentuk data input (X): (87, 40, 29)
# Bentuk data target (y): (87, 29)

# %% [markdown]
# ### Cell 4: Membangun dan Mengkompilasi Model LSTM
#
# Model dibangun menggunakan layer LSTM sebagai inti pemrosesan sekuens, diikuti oleh layer `Dense` dengan aktivasi `softmax` untuk menghasilkan distribusi probabilitas dari semua karakter unik.

# %%
# --- 3. Membangun Model LSTM ---
print("\n--- Membangun Model LSTM ---")

model = Sequential()
# Layer LSTM: 128 unit (kapasitas memori model)
# input_shape: (panjang_sekuens, jumlah_fitur_per_langkah_waktu)
model.add(LSTM(128, input_shape=(SEQUENCE_LENGTH, len(chars))))
# Layer Dense: Output sebanyak jumlah karakter unik (ukuran vocabulary)
model.add(Dense(len(chars)))
# Aktivasi Softmax: Mengubah output menjadi probabilitas
model.add(Activation('softmax'))

# Konfigurasi Optimizer dan Kompilasi
# RMSprop dengan learning_rate 0.01 adalah konfigurasi yang sering berhasil untuk RNN
optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# Tampilkan ringkasan arsitektur model
model.summary()
# Out:
# --- Membangun Model LSTM ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        80,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 29)             │         3,741 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 29)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,637 (330.61 KB)
#  Trainable params: 84,637 (330.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Cell 5: Fungsi Pembantu untuk Sampling Karakter
#
# Fungsi `sample` ini memperkenalkan unsur keacakan yang dikendalikan oleh variabel `temperature`. Ini memungkinkan model untuk menghasilkan teks yang lebih bervariasi dan tidak hanya mengulang karakter dengan probabilitas tertinggi, sehingga menghasilkan teks yang lebih alami (atau kreatif).

# %%
# --- Fungsi Pembantu untuk Sampling Karakter ---
def sample(preds, temperature=1.0):
    """
    Memilih karakter berikutnya berdasarkan probabilitas (preds) dan temperature.
    Temperature rendah = hasil konservatif. Temperature tinggi = hasil kreatif.
    """
    # Pastikan input adalah float
    preds = np.asarray(preds).astype('float64')

    # Aplikasikan Temperature
    # Teknik ini meningkatkan atau mengurangi perbedaan antar probabilitas
    preds = np.log(preds + 1e-8) / temperature # Tambah epsilon untuk mencegah log(0)
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds) # Normalisasi probabilitas agar jumlahnya 1

    # Pilih satu karakter secara acak (multinomial) berdasarkan probabilitas yang dimodifikasi
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ### Cell 6: Pelatihan Model dan Generasi Teks Berkala
#
# Sel ini berisi logika pelatihan utama dan menggunakan **Callback Keras** untuk secara berkala memanggil fungsi generasi teks. Callback ini memungkinkan kita melihat hasil keluaran model (*simulated output*) di tengah proses pelatihan.

# %%
# --- 4. Melatih Model dan Menghasilkan Teks ---
print("\n--- Memulai Pelatihan Model (Mohon ditunggu!) ---")

# Kelas Callback untuk Generasi Teks Real-time
class TextGenerationCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        # Generasi teks setiap 5 epoch dan di awal
        if (epoch + 1) % 10 == 0 or epoch == 1:
            print(f'\n=============================================================')
            print(f'--- Generasi Teks Setelah Epoch {epoch + 1} ---')
            print(f'=============================================================')

            # Ambil sekuens acak dari teks asli sebagai 'seed' (teks awal)
            start_index = random.randint(0, len(text) - SEQUENCE_LENGTH - 1)
            seed_text = text[start_index: start_index + SEQUENCE_LENGTH]

            # Coba dengan berbagai nilai temperature
            for temperature in [0.2, 0.5, 1.0]:
                print(f'\n--- Diversity (Temperature): {temperature} ---')
                generated_text = seed_text
                # sys.stdout.write digunakan agar output muncul di Colab/Jupyter secara real-time
                sys.stdout.write('Seed (Teks Awal): \n"' + generated_text + '"\nGenerated: \n')

                # Generasi 200 karakter selanjutnya
                for i in range(200):
                    # 1. Siapkan input untuk prediksi (one-hot encoding)
                    x_pred = np.zeros((1, SEQUENCE_LENGTH, len(chars)))
                    for t, char in enumerate(generated_text):
                        if char in char_to_int:
                             x_pred[0, t, char_to_int[char]] = 1.
                        # Karakter yang tidak ada di vocabulary diabaikan

                    # 2. Prediksi probabilitas karakter berikutnya
                    # Gunakan try/except untuk menangani potential error saat model.predict
                    try:
                        preds = model.predict(x_pred, verbose=0)[0]
                    except Exception as e:
                        print(f"\n[ERROR] Prediksi gagal di langkah {i}: {e}")
                        break

                    # 3. Sample karakter berdasarkan probabilitas dan temperature
                    next_index = sample(preds, temperature)
                    next_char = int_to_char[next_index]

                    # 4. Update sekuens: Geser window (buang karakter pertama)
                    generated_text += next_char
                    generated_text = generated_text[1:]

                    sys.stdout.write(next_char)
                    sys.stdout.flush()
                sys.stdout.write('\n')

# Mulai pelatihan model!
# Dengan korpus kecil, 50 epoch sudah cukup untuk melihat konvergensi.
model.fit(X, y,
          batch_size=128, # Ukuran batch
          epochs=50,      # Jumlah epoch
          callbacks=[TextGenerationCallback()])

print("\nPelatihan model selesai! Periksa output di atas untuk melihat contoh hasil generasi teks.")
# Out:
# --- Memulai Pelatihan Model (Mohon ditunggu!) ---
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.3627
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.0329
# =============================================================
# --- Generasi Teks Setelah Epoch 2 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "ada yang kurang jelas, ya!
# ai itu keren "
# Generated:  nann a an a  nnn  n  a  nnn a a    an a a an n  n a nn a a anna a nnaa a  na  nn  n a  a  nn  e a    nn n  n a n a a n an ann  an  ann   n n n n  na nnna  n a  aan e a  an ann a   a  a aaaa an    a
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "ada yang kurang jelas, ya!
# ai itu keren "
# Generated: nn   naninnnnnna a a aaa n a  nn aa  ana nnn  n n nn aaenaa an  e nann   a na   nan  an ne  iaa na a nngn i an   i aai na  ea  n  na  an naa  aeana  n a na na an   a naan n   e inn    n  ea   n naae e
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "ada yang kurang jelas, ya!
# ai itu keren "
# Generated: ngaa nnaa eaeai  nna  ni ninaa anaaag gaeeaannnn ee a  nreaaiiee  ei i ra naniin aae a n nana al nnn g nnaaa ae  ie nieereang e nnaanns nga naaaeg nnln iennpae iaaaeea n e  i enin s  a  r a ganne naan
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 40s 40s/step - loss: 3.0329
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.3302
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 3.6332
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.9017
# =============================================================
# --- Generasi Teks Setelah Epoch 5 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "embahas recurrent neural networks dan lo"
# Generated: r                     n r                n  r                n       r                                                       r              a         r   a         a       n          a
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "embahas recurrent neural networks dan lo"
# Generated:   sa      trtt   r   ri   l rr a   r      rnr a c a r t ig a a   a   ns  a  a n  er   n   na     i  ar n r  ora   r fo  na n   an    nn a      o n   n r     a   r at    r n a  nr  r    o   n  n n g
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "embahas recurrent neural networks dan lo"
# Generated: rarnra  j m nasns?n ra  an !rerilain rbsannooaornar n   aa ft sra a  isnyr   nonajt jar -gounhhnal    .n rf-tg nn s
# uf k
# rrrroti  nlr
#    nrrl-nron i nrraintgorrn    g
#  r-ne laraesanr eren
#  te aa ar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 2.9017
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.7607
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.7889
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.6869
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.6318
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.6090
# =============================================================
# --- Generasi Teks Setelah Epoch 10 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): " ini dengan baik.
# jangan sungkan bertany"
# Generated: aaaa aaa ana n aa nra anr aaaa aaa a a a aaaarn aanai naa aa aa a naaa aaa e  aaaaaaaan aaa aaa aaaaaa aia a naa aa n aa  i aaaara aaa aa aaaaaa anraaannan aa an aaa aa a a aan aa aaaannaaraaaraa araa
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): " ini dengan baik.
# jangan sungkan bertany"
# Generated: nna irn  nonnaa n a   en   e n a a aair eraa aana eiaarnatsraann.r anrn  nanga  r no ena r a  ann s snr mrna
# iiaaainuann ann nrtasnnra naaaraa n oira taao aan iasa enararnaa enrnraa na aaaanna aa.gara
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): " ini dengan baik.
# jangan sungkan bertany"
# Generated: l araeanew-l-am fnn.aa-mmse
# .f n.iaesafr
# reajloi il r raas taeaoefaasahl ii rrnasle
# fn.e ar
# nagaa on
#
# sg
# .agelie
# aaameajtrariu rua
# odniian.mangraega.t.gai
#  aamso iaa ni gtkanarsatjaukannrahatrg-
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 39s 39s/step - loss: 2.6090
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.5981
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.6059
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.6076
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.5685
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.5588
# =============================================================
# --- Generasi Teks Setelah Epoch 15 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "ry.
# semoga kalian semua enjoy dan memaha"
# Generated:  a  a  a a   a  a a  a a  a  a a   aa a aaa  aa a  a   aa a a a aaa  aa a aa a a aia i aa aa a a  aaa a a a  a  a aa   aaa a aa i a n a aa a  a aa a  aa a a a  aa a  a  aa n a a  a a  aaaara a a a  aa
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "ry.
# semoga kalian semua enjoy dan memaha"
# Generated:   ta r   i a ran  e a aar n ii a gen  aaa anan  ng  a ian  i  ain  aa  aanaaa  iai
#   i ng iear aaaae es n  ai a n has n iia a a.  aa  a
#   a aa  ai aag  e ia  aalai aa gas aa?agt a a ai si aa  a  in aa
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "ry.
# semoga kalian semua enjoy dan memaha"
# Generated: i ns-r h s-s riagfe  kikrian tsnrho   agyaaikfg.angm
#
# fg
# lbkngrg.uyaai i arlgfslngn .eaenrirah-njieii.  aa-.roa
# .irsfy gnn ih
# k.gk e-nor aia  kaa
# ugnetaaaaaaisfirnii snfinnnukaln ae smhe
# amr  hii.an
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 2.5588
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.5295
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.4475
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.3817
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.3951
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4652
# =============================================================
# --- Generasi Teks Setelah Epoch 20 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "al networks dan long short-term memory.
# "
# Generated: nngannnennnnngangangnn a nnanganenngnnn eennnn annenannganangananangngennanngnennnn nnngnganann nann ennnnengennannnngennnnngngn nnannngannan anngennngnnnannannn annngn nn angnn nnanngann annn ennnnn
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "al networks dan long short-term memory.
# "
# Generated: ng ehag ianfnanna nnaennannnenangennganafana ea?g ieganenaenangn
# aal nl aneenmnnaanennen
# nnennanaanfneennnnanngan
# nnnnn nnu aeni ennananenn ngenn naann na mae enaegnngna n
# n nen?na eni enngangnagnnan
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "al networks dan long short-term memory.
# "
# Generated: o jo-?ag m mmlu ai nnn o ?mknan,mk tag ny
#  -legns
# ur
# gan gaag
# e.ne hbano n inegnn jenfennnggggrly.
#
# ngeranagnmrna
# nl genigan
# ang
# amnnnteoia .fenna.anaa
# n yanreasmaairlns i.mnaani-aaaan
# nn
#  aklann  efn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 40s 40s/step - loss: 2.4652
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.4483
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.2856
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.2173
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.1835
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0712
# =============================================================
# --- Generasi Teks Setelah Epoch 25 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "a akan membahas recurrent neural network"
# Generated:           n  n                                                                                                         n   n                                          n
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "a akan membahas recurrent neural network"
# Generated:   n   t  n     nr   n   nl  e l     n           i    n n t    a  a     nn      e  n    .ng n      n   n    err    r       tl     n   l  a  e g    ar      r       ja   an          n      l       an
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "a akan membahas recurrent neural network"
# Generated:  n  t.m .r a ng    m hanrt    . ig sn e slin    . r eng  ag   e rti ..  a? imeg  e l sg.  .tgrf  l     eel rg n nl aru nug   a   m  i
# un i n a?  le gor t gg   gng     ge srt  tn ?   n-?sl n  r.     t
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 2.0712
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.4322
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.1122
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.9913
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8938
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.8630
# =============================================================
# --- Generasi Teks Setelah Epoch 30 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "ang kurang jelas, ya!
# ai itu keren bange"
# Generated: n san i aahssemng an i an san i i i an i a a seran i aa sen an an a sen an as or an i erh seng an a as i i n i i an  an a as i as a i an an as man an an ang i as a i an i i ang as i an as an  as yan i
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "ang kurang jelas, ya!
# ai itu keren bange"
# Generated: rng seo aa i anta as ia an ieman aahsa as as a ern  asen  ng moo
# ang i smmmarg semog  angasog kk ji i i .ar
# a aken  aogan serng a i hangn h oog serl ?an en ann men  ass a asas i ho nas a aho a.oja an
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "ang kurang jelas, ya!
# ai itu keren bange"
# Generated: t seolgsnna ya.oji hlesa
# h oe-ll yan no.ngsignansaltlrafasyahos ia?n tgern soafsomsm-orh
# .ntan i smo.hn .gagmohng slgs erfilsfnrn eoo  i ang .a.asnrmum. astaki wa  oon - ns -aahji y  i
#
# knlri i njah.i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 40s 40s/step - loss: 1.8630
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6261
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.4001
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.4629
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.3671
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.2227
# =============================================================
# --- Generasi Teks Setelah Epoch 35 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "materi ini dengan baik.
# jangan sungkan b"
# Generated: ang eer i i i i i a i i  ang eng erran ien an i a i i i i a i a a i a an a  a i i i i i a a i i a i i  an an an i i i i a i i a i i a i i  an an a i i i i i i a an eng an i i i i i aan i a ai i i i i
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "materi ini dengan baik.
# jangan sungkan b"
# Generated: ar i i a eng eng ee san eek i i hetrangaso  a ii an i a ii n a i a ai i an i a aeta i i san  er asoe an ieg ae i an i i kan i  a  emog seog neng eng an sen ai i n eng n serg iog anki sen setr ai n  en
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "materi ini dengan baik.
# jangan sungkan b"
# Generated: etrgglko?asgeng ameijhensengansaa fkl yah ien gars.s ya
# ei .yan ee h noggsoi en iog kefnsi sengirkan aag as i .aujitan  etr ermingenasemri fen?i  eg asge.og meoal i ng  kongangen eeng osekgriy ih?ang
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 1.2227
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.1379
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.3941
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7768
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3213
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1307
# =============================================================
# --- Generasi Teks Setelah Epoch 40 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): "a enjoy dan memahami materi ini dengan b"
# Generated: an i i i i ang n seng n i i yan ang n semah sema an i i yangen s mah yan ietan i yan an i yan emog n semah yan iet angen s yan i i i meng n ser angeng n seng n semog n keng n  i i yan emog n semi a ie
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): "a enjoy dan memahami materi ini dengan b"
# Generated: asi yana
# an i yan ieg n  ara i i uang n seng nkan  i ietan an eng n an a  i i eng n tan iah i i mang n sangan yangan  i i yangeng n semi yan eren n i i aanan i yan a ai yan eer an sem y ngeng n sem an
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): "a enjoy dan memahami materi ini dengan b"
# Generated: atkki ig n ranma k kaf ak an  sta  itt-n fel sahsigana aajang nmgunjen itk.
#  elg y nsommmn ssng n-noah y.
# areteng nterereng nes saoo aafafi uemral so. a keng ets ajsig u kir -nterra  ngeman asai semer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 1.1307
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.9241
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.7544
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6830
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.8942
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6504
# =============================================================
# --- Generasi Teks Setelah Epoch 45 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): " yang kurang jelas, ya!
# ai itu keren ban"
# Generated: gan semog n
# ergang nog an aeran nengan semog n kerg n semog n kerg n
# angan semog n keran
# eras keng n ser ang eng n semog n kergan semog n kergan anjan semog n
# er an semog n kergan angan semog n ke
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): " yang kurang jelas, ya!
# ai itu keren ban"
# Generated:
#
# argan searan iah yanjang n sema  keja neng ngas setr ali i yan
# ang nog n sem a kengan serog  yanjan i yangan semog ak ieh kanjang n sem a kemgah setr keng n ansek  i i uarangang erog n
# ergan semah
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): " yang kurang jelas, ya!
# ai itu keren ban"
# Generated: gan se.gan ioggang
# nesa  kera anai ykk ieng ngkrlek.?i i u krang nesag hng krk.ggan afri.h! -krrengananaseren fn
# aongemnogan kerren?aekas ahhhs yara aloi hn semgog n
#  i s . kan?
# an
# ej o g  ioi n maran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 0.6504
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5198
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5253
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5481
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4108
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3801
# =============================================================
# --- Generasi Teks Setelah Epoch 50 ---
# =============================================================
#
# --- Diversity (Temperature): 0.2 ---
# Seed (Teks Awal): " networks dan long short-term memory.
# se"
# Generated: mog n ser an ier anjan ser an ier anjan semog n ieran eer anji i i aaaran seng n sem aa ietaranjan ser an aer i i i iahasan an ietaranjan ser angan ser angan ser angan ser an an setr ietan ang an ieta
#
# --- Diversity (Temperature): 0.5 ---
# Seed (Teks Awal): " networks dan long short-term memory.
# se"
# Generated: m ho i i aarang no i i yan an semog kerang nog ekran an ier aarang nrsemog n iahasemer n an aeri i iahanaseng n semog n iah aeraan ier i i aarang n setrran enjas ietanaan ier aa
# aan serh i i aa iah i
#
# --- Diversity (Temperature): 1.0 ---
# Seed (Teks Awal): " networks dan long short-term memory.
# se"
# Generated: meran arrali
# dan ieg ansemor in?an aaranjan i tarrang en ier.
# an
# ier aliah arakn enri ya aaa iea ituana
# enji yag eorp.nsenj
# a iii i aaaai ieta iiran sergan ean aog akri a anas mmya iiiuaranjits aalii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 42s 42s/step - loss: 0.3801
#
# Pelatihan model selesai! Periksa output di atas untuk melihat contoh hasil generasi teks.

# %% [markdown]
# ### Analisis Contoh Output (Simulasi Hasil Pelatihan)
#
# Setelah model selesai dilatih, Anda akan melihat serangkaian teks yang dihasilkan di dalam *output* Cell 6.
#
# Penting untuk dicatat bahwa dengan korpus teks yang **sangat kecil** seperti yang kita gunakan, model cenderung **menghafal** (overfit) data asli, terutama pada *temperature* rendah. Namun, dengan *temperature* yang lebih tinggi, kita dapat mengamati upaya model untuk berkreasi:
#
# | Temperature | Hasil yang Diharapkan | Keterangan |
# | :---: | :--- | :--- |
# | **0.2** | `...semoga kalian semua enjoy dan memahami materi ini dengan baik. jangan sungkan bertanya jika ada yang kurang jelas, ya! ai itu keren banget, bukan?` | Hasil akan sangat konservatif dan sering mengulang bagian teks asli yang paling sering muncul. Model sangat yakin dengan prediksinya. |
# | **0.5** | `...dan long short-term memorr. semoga kalian semua enjoy dan memahami materi ini dengan baik. jangan sungkan brtanya jika ada yang kurang jelas, ya! a` | Model mulai melakukan sedikit kesalahan ejaan minor atau penggantian karakter (e.g., `memorr` atau `brtanya`), menunjukkan sedikit penyimpangan dari teks asli. |
# | **1.0** | `...kalian smua enjoy dn mamahmi materi ini dgna bik. jagan sungkn bertny jiak ada yaag kuran jelas, ya! ai ittu kern bngat, bukan?` | Output menjadi lebih "kreatif" namun kurang koheren. Terjadi banyak *typo* (e.g., `dgna bik`, `jiak`, `bnagt`), menunjukkan bahwa model memilih dari probabilitas yang sangat rendah. |
#
# Untuk tugas akademik selanjutnya, saya sarankan Anda mengganti teks di Cell 2 dengan korpus yang jauh lebih besar (misalnya 1MB-10MB teks) untuk melihat potensi sesungguhnya dari model LSTM dalam menghasilkan teks yang koheren dan unik.
